# %%
from roboflow import Roboflow

rf = Roboflow(api_key="") # Change Your API Key
project = rf.workspace("").project("ppe-dataset-for-workplace-safety-is4dn")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# ...
# Extracting Dataset Version Zip to PPE-Dataset-for-Workplace-Safety-1 in yolov11:: 100%|██████████| 3220/3220 [00:14<00:00, 229.44it/s]
